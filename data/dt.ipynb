# %%
import eastmoney as et
import csindex as ci
import cn

# %%
csi = ci.cnSecurityIndustry()
for v in csi:
    code = v['securityCode']
    print(code)
    # charts = et.cn_chartbar(cn.codeToSymbol(code))

# %%
charts = et.cn_chartbar(cn.codeToSymbol('600036'))
df = et.to_df2(charts)

# %%
df
# Out:
#              open   high    low  close        volume
# date
# 2020-01-02  38.03  39.12  38.02  38.88  3.191181e+09
# 2020-01-03  38.95  39.62  38.92  39.40  2.045230e+09
# 2020-01-06  39.19  40.16  38.90  39.24  2.171576e+09
# 2020-01-07  39.55  39.94  39.10  39.15  1.369305e+09
# 2020-01-08  38.95  38.95  38.41  38.41  1.403861e+09
# ...           ...    ...    ...    ...           ...
# 2022-12-12  36.41  36.60  35.68  35.79  2.186064e+09
# 2022-12-13  35.73  36.26  35.61  36.14  1.379130e+09
# 2022-12-14  36.14  37.04  36.02  36.91  2.361876e+09
# 2022-12-15  36.62  36.96  36.22  36.33  1.470345e+09
# 2022-12-16  36.30  37.20  36.30  37.09  2.242781e+09
#
# [718 rows x 5 columns]
