# %%
import akshare as ak

# %%
df = ak.crypto_js_spot()
df
# Out:
#                市场    交易品种         最近报价       涨跌额   涨跌幅      24小时最高  \
# 0    Bitfinex(香港)  LTCUSD       93.138     -1.75 -1.85       95.46
# 1    Bitflyer(日本)  BTCJPY  4204829.000  14377.00  0.34  4229000.00
# 2    Bitstamp(美国)  BTCUSD    30311.000    141.00  0.47    30442.00
# 3      CEX.IO(伦敦)  BTCUSD    30320.300    124.10  0.41    30417.60
# 4  Kraken_EUR(美国)  BTCEUR    27000.000    106.50  0.40    27151.40
# 5      Kraken(美国)  LTCUSD       93.000     -1.71 -1.81       95.30
# 6      OKCoin(中国)  BTCUSD    30550.600   -448.40 -1.45    30999.00
# 7    Bitfinex(香港)  BCHUSD        0.000      0.00  0.00        0.00
# 8    Bitfinex(香港)  BTCUSD    30330.000    138.00  0.46    30484.00
# 9      Kraken(美国)  BTCUSD    30299.900    129.50  0.43    30447.50
#
#         24小时最低   24小时成交量                 更新时间
# 0       91.937   6694.27  2023-07-17 13:02:04
# 1  4188204.000    416.72  2023-07-17 13:02:04
# 2    30153.000    915.98  2023-07-17 13:02:04
# ...
