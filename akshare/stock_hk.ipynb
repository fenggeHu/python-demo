# %%
import akshare as ak

# %%
# 实时行情数据-东财
stock_hk_spot_em_df = ak.stock_hk_spot_em()
stock_hk_spot_em_df

# %%
# 主板实时行情数据-东财
stock_hk_main_board_spot_em_df = ak.stock_hk_main_board_spot_em()
stock_hk_main_board_spot_em_df

# %%
# 实时行情数据-新浪
stock_hk_spot_df = ak.stock_hk_spot()
stock_hk_spot_df

# %%
# 分时数据-东财
stock_hk_hist_min_em_df = ak.stock_hk_hist_min_em(symbol="00700", period='1', adjust='',
                                                  start_date="2023-08-01 09:30:00",
                                                  end_date="2023-08-07 15:00:00")  # 其中的 start_date 和 end_date 需要设定为近期
stock_hk_hist_min_em_df
# Out:
#                      时间     开盘     收盘     最高     最低     成交量          成交额  \
# 0   2023-08-01 09:30:00  356.0  356.0  356.4  356.0  533600  189961600.0
# 1   2023-08-01 09:31:00  355.2  355.4  356.8  355.0  338300  120386700.0
# 2   2023-08-01 09:32:00  355.6  355.6  356.6  355.2  294600  104874900.0
# 3   2023-08-01 09:33:00  355.6  355.8  356.6  355.0  327500  116481180.0
# 4   2023-08-01 09:34:00  356.0  356.0  356.8  355.8  220300   78472060.0
# ..                  ...    ...    ...    ...    ...     ...          ...
# 83  2023-08-01 10:53:00  355.6  354.6  355.8  354.6  112600   39991000.0
# 84  2023-08-01 10:54:00  354.8  355.4  355.6  354.6  113000   40115420.0
# 85  2023-08-01 10:55:00  355.6  355.6  355.8  355.4   62100   22079840.0
# 86  2023-08-01 10:56:00  355.6  355.8  355.8  355.2   78900   28049560.0
# 87  2023-08-01 10:57:00  355.6  356.0  356.4  355.6   25200    8970460.0
#
#          最新价
# 0   356.0000
# 1   355.9448
# 2   355.9565
# 3   355.8932
# 4   355.9333
# ...
